# %%
import pandas as pd

# %%
# importamos dataset
df = pd.read_csv('data/data_2022-04-01_2022-04-02.csv')
# remove Unnamed: 0
df = df.drop(columns=['Unnamed: 0'])

# %%
# remove column 0 
df
# Out:
#        id_news                                              title label  \
# 0   47135604.0  Diputados UDI piden información a  municipalid...   NEU
# 1   47136121.0  Panquehue implementa aplicación lectora de pat...   POS
# 2   47136140.0  Dos personas fallecidas dejó accidente de trán...   NEG
# 3   47136168.0  Nuevo ataque incendiario dejó un camión destru...   NEG
# 4   47137055.0  PDi detuvo a 4 personas por tráfico en Laguna ...   POS
# 5   47137152.0  Fintech Clever lanza ambicioso programa de ref...   POS
# 6   47138493.0  Murió Luis Cortes Villa, expresidente de la fu...   POS
# 7   47138503.0  Presidente Gabriel Boric encabeza primera reun...   POS
# 8   47140850.0  Hospital reconoce el compromiso y dedicación d...   POS
# 9   47144093.0  En ajuste de cuentas disparan a ciudadano hait...   NEG
# 10  47144165.0  Desde mañana al fin empieza a rodar el balón e...   POS
# 11  47144169.0  Unos mil contribuyentes serán asesorados por a...   POS
# ...
